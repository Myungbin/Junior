# %%
import pandas as pd

# %%
for i in range(1, 100):
    j = str(i)
    if '3' in str(i):
        print('짝')
    elif '6' in str(i):
        print('짝')
    elif '9' in str(i):
        print('짝')
    else:
        print(i)
# Out:
# 1
# 2
# 짝
# 4
# 5
# 짝
# 7
# 8
# 짝
# 10
# 11
# 12
# 짝
# 14
# 15
# 짝
# 17
# 18
# 짝
# 20
# 21
# 22
# 짝
# 24
# 25
# 짝
# 27
# 28
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 40
# 41
# 42
# 짝
# 44
# 45
# 짝
# 47
# 48
# 짝
# 50
# 51
# 52
# 짝
# 54
# 55
# 짝
# 57
# 58
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 70
# 71
# 72
# 짝
# 74
# 75
# 짝
# 77
# 78
# 짝
# 80
# 81
# 82
# 짝
# 84
# 85
# 짝
# 87
# 88
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
# 짝
